# %% [markdown]
# # Prework

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 0.1 sizes相关的函数测试

# %%
# sizes_path = "/media/sdd_14T/translocation/HiC_default/chrom_yZSJ025.sizes"
sizes_path = "/media/sdd_14T/translocation/HiC_default/chrom_hg19.sizes"
sizes = pd.read_csv(sizes_path,sep='\t',header=None)
sizes
# Out:
#         0          1
# 0    chr1  249250621
# 1    chr2  243199373
# 2    chr3  198022430
# 3    chr4  191154276
# 4    chr5  180915260
# 5    chr6  171115067
# 6    chr7  159138663
# 7    chr8  146364022
# 8    chr9  141213431
# 9   chr10  135534747
# 10  chr11  135006516
# 11  chr12  133851895
# 12  chr13  115169878
# 13  chr14  107349540
# 14  chr15  102531392
# 15  chr16   90354753
# 16  chr17   81195210
# 17  chr18   78077248
# 18  chr19   59128983
# 19  chr20   63025520
# 20  chr21   48129895
# 21  chr22   51304566
# 22   chrX  155270560

# %%
def sizes2chrname(sizes):
    chrname = [sizes[0][i] for i in range(len(sizes))]
    return chrname
def sizes2MaxChrLen(sizes):
    return np.max(sizes[1])
def sizes2resUnit(sizes):
    return int(pow(10,len(str(int(np.max(sizes[1])/10000)))))
def num2res_sim(num):
    if (num/1000000>=1):
        return str(int(num/1000000))+'M'
    else:
        if (num/1000>=1):
            return str(int(num/1000))+'k'
def chrname_pre(chrname_i):
    if chrname_i.startswith('chr'):
        return ''
    else:
        return 'chr'
chrname = sizes2chrname(sizes)
chrname
sizes2MaxChrLen(sizes),sizes2resUnit(sizes),num2res_sim(sizes2resUnit(sizes)*5),sizes[0][1].startswith('chr')
# Out:
# (249250621, 100000, '500k', True)

# %% [markdown]
# # Input Test

# %% [markdown]
# ## 1.1 hic2mat

# %%
from HiSTra.hicInput import hic2mat
input_test_path = "/media/sdd_14T/hic/Rao_K562_hg19_hicfile.allValidPairs.hic"
input_control_path = "/media/sdd_14T/hic/Rao_IMR90_hg19_hicfile.allValidPairs.hic"
output_path = "/media/sdd_14T/translocation/work_dir"
sizes_path = "/media/sdd_14T/translocation/HiC_default/chrom_hg19.sizes"
juice_path = "/media/sdd_14T/translocation/Code/HiSTra/juice/juicer_tools_2.09.00.jar"
sizes = pd.read_csv(sizes_path,sep='\t',header=None)
print(hic2mat(input_test_path,output_path,juice_path,sizes))
print(hic2mat(input_control_path,output_path,juice_path,sizes))
# Out:
# --------- The hic file path is /media/sdd_14T/hic/Rao_K562_hg19_hicfile.allValidPairs.hic. ---------
# --------- We are dumpping Rao_K562_hg19_hicfile sample chromosome pairs ('chr1', 'chr1').
# --------- Process is completed 0.0%... ---------
# --------- We are dumpping Rao_K562_hg19_hicfile sample chromosome pairs ('chr2', 'chr2').
# --------- Process is completed 8.695652173913043%... ---------
# --------- We are dumpping Rao_K562_hg19_hicfile sample chromosome pairs ('chr3', 'chr3').
# --------- Process is completed 16.99604743083004%... ---------
# --------- We are dumpping Rao_K562_hg19_hicfile sample chromosome pairs ('chr4', 'chr4').
# --------- Process is completed 24.90118577075099%... ---------
# --------- We are dumpping Rao_K562_hg19_hicfile sample chromosome pairs ('chr5', 'chr5').
# --------- Process is completed 32.41106719367589%... ---------
# --------- We are dumpping Rao_K562_hg19_hicfile sample chromosome pairs ('chr6', 'chr6').
# --------- Process is completed 39.52569169960474%... ---------
# --------- We are dumpping Rao_K562_hg19_hicfile sample chromosome pairs ('chr7', 'chr7').
# --------- Process is completed 46.24505928853755%... ---------
# --------- We are dumpping Rao_K562_hg19_hicfile sample chromosome pairs ('chr8', 'chr8').
# --------- Process is completed 52.569169960474305%... ---------
# --------- We are dumpping Rao_K562_hg19_hicfile sample chromosome pairs ('chr9', 'chr9').
# --------- Process is completed 58.49802371541502%... ---------
# --------- We are dumpping Rao_K562_hg19_hicfile sample chromosome pairs ('chr10', 'chr10').
# --------- Process is completed 64.03162055335969%... ---------
# --------- We are dumpping Rao_K562_hg19_hicfile sample chromosome pairs ('chr11', 'chr11').
# --------- Process is completed 69.1699604743083%... ---------
# --------- We are dumpping Rao_K562_hg19_hicfile sample chromosome pairs ('chr12', 'chr12').
# --------- Process is completed 73.91304347826087%... ---------
# --------- We are dumpping Rao_K562_hg19_hicfile sample chromosome pairs ('chr13', 'chr13').
# --------- Process is completed 78.26086956521739%... ---------
# --------- We are dumpping Rao_K562_hg19_hicfile sample chromosome pairs ('chr14', 'chr14').
# --------- Process is completed 82.21343873517786%... ---------
# --------- We are dumpping Rao_K562_hg19_hicfile sample chromosome pairs ('chr15', 'chr15').
# --------- Process is completed 85.7707509881423%... ---------
# --------- We are dumpping Rao_K562_hg19_hicfile sample chromosome pairs ('chr16', 'chr16').
# --------- Process is completed 88.93280632411067%... ---------
# --------- We are dumpping Rao_K562_hg19_hicfile sample chromosome pairs ('chr17', 'chr17').
# --------- Process is completed 91.699604743083%... ---------
# --------- We are dumpping Rao_K562_hg19_hicfile sample chromosome pairs ('chr18', 'chr18').
# --------- Process is completed 94.07114624505928%... ---------
# --------- We are dumpping Rao_K562_hg19_hicfile sample chromosome pairs ('chr19', 'chr19').
# --------- Process is completed 96.04743083003953%... ---------
# --------- We are dumpping Rao_K562_hg19_hicfile sample chromosome pairs ('chr20', 'chr20').
# --------- Process is completed 97.62845849802372%... ---------
# --------- We are dumpping Rao_K562_hg19_hicfile sample chromosome pairs ('chr21', 'chr21').
# --------- Process is completed 98.81422924901186%... ---------
# --------- We are dumpping Rao_K562_hg19_hicfile sample chromosome pairs ('chr22', 'chr22').
# --------- Process is completed 99.60474308300395%... ---------
# --------- We are dumpping Rao_K562_hg19_hicfile sample chromosome pairs ('chrX', 'chrX').
# --------- Process is completed 100.0%... ---------
# You can check juicer_100k_log.txt and juicer_500k_log.txt in current directory if any error occurs.
# /media/sdd_14T/translocation/work_dir/Matrix_from_hic/Rao_K562_hg19_hicfile
# --------- The hic file path is /media/sdd_14T/hic/Rao_IMR90_hg19_hicfile.allValidPairs.hic. ---------
# --------- We are dumpping Rao_IMR90_hg19_hicfile sample chromosome pairs ('chr1', 'chr1').
# --------- Process is completed 0.0%... ---------
# --------- We are dumpping Rao_IMR90_hg19_hicfile sample chromosome pairs ('chr2', 'chr2').
# --------- Process is completed 8.695652173913043%... ---------
# --------- We are dumpping Rao_IMR90_hg19_hicfile sample chromosome pairs ('chr3', 'chr3').
# --------- Process is completed 16.99604743083004%... ---------
# --------- We are dumpping Rao_IMR90_hg19_hicfile sample chromosome pairs ('chr4', 'chr4').
# --------- Process is completed 24.90118577075099%... ---------
# --------- We are dumpping Rao_IMR90_hg19_hicfile sample chromosome pairs ('chr5', 'chr5').
# --------- Process is completed 32.41106719367589%... ---------
# --------- We are dumpping Rao_IMR90_hg19_hicfile sample chromosome pairs ('chr6', 'chr6').
# --------- Process is completed 39.52569169960474%... ---------
# --------- We are dumpping Rao_IMR90_hg19_hicfile sample chromosome pairs ('chr7', 'chr7').
# --------- Process is completed 46.24505928853755%... ---------
# --------- We are dumpping Rao_IMR90_hg19_hicfile sample chromosome pairs ('chr8', 'chr8').
# --------- Process is completed 52.569169960474305%... ---------
# --------- We are dumpping Rao_IMR90_hg19_hicfile sample chromosome pairs ('chr9', 'chr9').
# --------- Process is completed 58.49802371541502%... ---------
# --------- We are dumpping Rao_IMR90_hg19_hicfile sample chromosome pairs ('chr10', 'chr10').
# --------- Process is completed 64.03162055335969%... ---------
# --------- We are dumpping Rao_IMR90_hg19_hicfile sample chromosome pairs ('chr11', 'chr11').
# --------- Process is completed 69.1699604743083%... ---------
# --------- We are dumpping Rao_IMR90_hg19_hicfile sample chromosome pairs ('chr12', 'chr12').
# --------- Process is completed 73.91304347826087%... ---------
# --------- We are dumpping Rao_IMR90_hg19_hicfile sample chromosome pairs ('chr13', 'chr13').
# --------- Process is completed 78.26086956521739%... ---------
# --------- We are dumpping Rao_IMR90_hg19_hicfile sample chromosome pairs ('chr14', 'chr14').
# --------- Process is completed 82.21343873517786%... ---------
# --------- We are dumpping Rao_IMR90_hg19_hicfile sample chromosome pairs ('chr15', 'chr15').
# --------- Process is completed 85.7707509881423%... ---------
# --------- We are dumpping Rao_IMR90_hg19_hicfile sample chromosome pairs ('chr16', 'chr16').
# --------- Process is completed 88.93280632411067%... ---------
# --------- We are dumpping Rao_IMR90_hg19_hicfile sample chromosome pairs ('chr17', 'chr17').
# --------- Process is completed 91.699604743083%... ---------
# --------- We are dumpping Rao_IMR90_hg19_hicfile sample chromosome pairs ('chr18', 'chr18').
# --------- Process is completed 94.07114624505928%... ---------
# --------- We are dumpping Rao_IMR90_hg19_hicfile sample chromosome pairs ('chr19', 'chr19').
# --------- Process is completed 96.04743083003953%... ---------
# --------- We are dumpping Rao_IMR90_hg19_hicfile sample chromosome pairs ('chr20', 'chr20').
# --------- Process is completed 97.62845849802372%... ---------
# --------- We are dumpping Rao_IMR90_hg19_hicfile sample chromosome pairs ('chr21', 'chr21').
# --------- Process is completed 98.81422924901186%... ---------
# --------- We are dumpping Rao_IMR90_hg19_hicfile sample chromosome pairs ('chr22', 'chr22').
# --------- Process is completed 99.60474308300395%... ---------
# --------- We are dumpping Rao_IMR90_hg19_hicfile sample chromosome pairs ('chrX', 'chrX').
# --------- Process is completed 100.0%... ---------
# You can check juicer_100k_log.txt and juicer_500k_log.txt in current directory if any error occurs.
# /media/sdd_14T/translocation/work_dir/Matrix_from_hic/Rao_IMR90_hg19_hicfile

# %% [markdown]
# ## 1.2 cool2mat

# %%
./HiST -t /media/sdd_14T/mcool/Rao_K562_hg19.mcool -c /media/sdd_14T/mcool/Rao_IMR90_hg19.mcool -s /media/sdd_14T/translocation/HiC_default/chrom_hg19.sizes -o /media/sdd_14T/translocation/work_dir
# Out:
# --------- The cool hic file path is /media/sdd_14T/mcool/Rao_K562_hg19.mcool. ---------
# --------- We are dumpping Rao_K562_hg19 sample chromosome pairs ('chr1', 'chr1').
# --------- Process is completed 0.0%... ---------
# --------- We are dumpping Rao_K562_hg19 sample chromosome pairs ('chr2', 'chr2').
# --------- Process is completed 8.695652173913043%... ---------
# --------- We are dumpping Rao_K562_hg19 sample chromosome pairs ('chr3', 'chr3').
# --------- Process is completed 16.99604743083004%... ---------
# --------- We are dumpping Rao_K562_hg19 sample chromosome pairs ('chr4', 'chr4').
# --------- Process is completed 24.90118577075099%... ---------
# --------- We are dumpping Rao_K562_hg19 sample chromosome pairs ('chr5', 'chr5').
# --------- Process is completed 32.41106719367589%... ---------
# --------- We are dumpping Rao_K562_hg19 sample chromosome pairs ('chr6', 'chr6').
# --------- Process is completed 39.52569169960474%... ---------
# --------- We are dumpping Rao_K562_hg19 sample chromosome pairs ('chr7', 'chr7').
# --------- Process is completed 46.24505928853755%... ---------
# --------- We are dumpping Rao_K562_hg19 sample chromosome pairs ('chr8', 'chr8').
# --------- Process is completed 52.569169960474305%... ---------
# --------- We are dumpping Rao_K562_hg19 sample chromosome pairs ('chr9', 'chr9').
# --------- Process is completed 58.49802371541502%... ---------
# --------- We are dumpping Rao_K562_hg19 sample chromosome pairs ('chr10', 'chr10').
# --------- Process is completed 64.03162055335969%... ---------
# --------- We are dumpping Rao_K562_hg19 sample chromosome pairs ('chr11', 'chr11').
# --------- Process is completed 69.1699604743083%... ---------
# --------- We are dumpping Rao_K562_hg19 sample chromosome pairs ('chr12', 'chr12').
# --------- Process is completed 73.91304347826087%... ---------
# --------- We are dumpping Rao_K562_hg19 sample chromosome pairs ('chr13', 'chr13').
# --------- Process is completed 78.26086956521739%... ---------
# --------- We are dumpping Rao_K562_hg19 sample chromosome pairs ('chr14', 'chr14').
# --------- Process is completed 82.21343873517786%... ---------
# --------- We are dumpping Rao_K562_hg19 sample chromosome pairs ('chr15', 'chr15').
# --------- Process is completed 85.7707509881423%... ---------
# --------- We are dumpping Rao_K562_hg19 sample chromosome pairs ('chr16', 'chr16').
# --------- Process is completed 88.93280632411067%... ---------
# --------- We are dumpping Rao_K562_hg19 sample chromosome pairs ('chr17', 'chr17').
# --------- Process is completed 91.699604743083%... ---------
# --------- We are dumpping Rao_K562_hg19 sample chromosome pairs ('chr18', 'chr18').
# --------- Process is completed 94.07114624505928%... ---------
# --------- We are dumpping Rao_K562_hg19 sample chromosome pairs ('chr19', 'chr19').
# --------- Process is completed 96.04743083003953%... ---------
# --------- We are dumpping Rao_K562_hg19 sample chromosome pairs ('chr20', 'chr20').
# --------- Process is completed 97.62845849802372%... ---------
# --------- We are dumpping Rao_K562_hg19 sample chromosome pairs ('chr21', 'chr21').
# --------- Process is completed 98.81422924901186%... ---------
# --------- We are dumpping Rao_K562_hg19 sample chromosome pairs ('chr22', 'chr22').
# --------- Process is completed 99.60474308300395%... ---------
# --------- We are dumpping Rao_K562_hg19 sample chromosome pairs ('chrX', 'chrX').
# --------- Process is completed 100.0%... ---------
# /media/sdd_14T/translocation/work_dir/Matrix_from_hic/Rao_K562_hg19

# %%
# Out:
#   Cell In[13], line 1
#     cooler dump -h
#            ^
# SyntaxError: invalid syntax
